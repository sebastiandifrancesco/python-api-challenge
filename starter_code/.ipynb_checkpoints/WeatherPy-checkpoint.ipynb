# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key
temp_units = 'imperial'

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Set URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# City and Set Number
city_num = 0
set_num = 1
# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if city_num > 48:
            city_num = 1
            set_num += 1
            city_two.append(city)
        else:
            city_num += 1
            city_two.append(city)
        print(f"Processing City Number {city_num} of set number {set_num}| {city}")
    except:
        print('no city found for this one')
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing City Number 1 of set number 1| talcahuano
# Processing City Number 2 of set number 1| bluff
# Processing City Number 3 of set number 1| albany
# Processing City Number 4 of set number 1| katsuura
# Processing City Number 5 of set number 1| saldanha
# Processing City Number 6 of set number 1| new norfolk
# no city found for this one
# Processing City Number 7 of set number 1| hobart
# Processing City Number 8 of set number 1| seryshevo
# Processing City Number 9 of set number 1| airai
# no city found for this one
# Processing City Number 10 of set number 1| punta arenas
# no city found for this one
# Processing City Number 11 of set number 1| kapaa
# Processing City Number 12 of set number 1| hermanus
# no city found for this one
# Processing City Number 13 of set number 1| ushuaia
# Processing City Number 14 of set number 1| micoud
# Processing City Number 15 of set number 1| santa isabel do rio negro
# Processing City Number 16 of set number 1| ribeira grande
# Processing City Number 17 of set number 1| bonavista
# Processing City Number 18 of set number 1| longyearbyen
# Processing City Number 19 of set number 1| cape town
# no city found for this one
# Processing City Number 20 of set number 1| esperance
# Processing City Number 21 of set number 1| dandong
# Processing City Number 22 of set number 1| genhe
# no city found for this one
# Processing City Number 23 of set number 1| atar
# Processing City Number 24 of set number 1| verkh-usugli
# Processing City Number 25 of set number 1| tucurui
# Processing City Number 26 of set number 1| seminole
# Processing City Number 27 of set number 1| kirakira
# Processing City Number 28 of set number 1| grand gaube
# Processing City Number 29 of set number 1| yar-sale
# Processing City Number 30 of set number 1| busselton
# Processing City Number 31 of set number 1| mekhe
# Processing City Number 32 of set number 1| sioux lookout
# Processing City Number 33 of set number 1| japura
# Processing City Number 34 of set number 1| derzhavinsk
# Processing City Number 35 of set number 1| campechuela
# Processing City Number 36 of set number 1| castro
# Processing City Number 37 of set number 1| mar del plata
# Processing City Number 38 of set number 1| east london
# Processing City Number 39 of set number 1| leningradskiy
# Processing City Number 40 of set number 1| feldbach
# Processing City Number 41 of set number 1| rio bonito
# Processing City Number 42 of set number 1| khatanga
# Processing City Number 43 of set number 1| rikitea
# Processing City Number 44 of set number 1| jamestown
# Processing City Number 45 of set number 1| port blair
# Processing City Number 46 of set number 1| barrow
# Processing City Number 47 of set number 1| ancud
# Processing City Number 48 of set number 1| atuona
# Processing City Number 49 of set number 1| fortuna
# Processing City Number 1 of set number 2| vardo
# Processing City Number 2 of set number 2| aswan
# Processing City Number 3 of set number 2| hasaki
# Processing City Number 4 of set number 2| olinda
# Processing City Number 5 of set number 2| talnakh
# no city found for this one
# Processing City Number 6 of set number 2| butaritari
# Processing City Number 7 of set number 2| kalmunai
# Processing City Number 8 of set number 2| sampit
# Processing City Number 9 of set number 2| qaanaaq
# Processing City Number 10 of set number 2| alekseyevka
# no city found for this one
# Processing City Number 11 of set number 2| tasiilaq
# Processing City Number 12 of set number 2| hambantota
# Processing City Number 13 of set number 2| riyadh
# Processing City Number 14 of set number 2| vaini
# Processing City Number 15 of set number 2| piacabucu
# Processing City Number 16 of set number 2| dikson
# Processing City Number 17 of set number 2| sahbuz
# Processing City Number 18 of set number 2| port augusta
# Processing City Number 19 of set number 2| bredasdorp
# Processing City Number 20 of set number 2| gorontalo
# no city found for this one
# Processing City Number 21 of set number 2| clyde river
# Processing City Number 22 of set number 2| satipo
# Processing City Number 23 of set number 2| norman wells
# Processing City Number 24 of set number 2| sobolevo
# Processing City Number 25 of set number 2| berdigestyakh
# Processing City Number 26 of set number 2| gat
# Processing City Number 27 of set number 2| pustoshka
# Processing City Number 28 of set number 2| sale
# no city found for this one
# no city found for this one
# no city found for this one
# Processing City Number 29 of set number 2| borogontsy
# Processing City Number 30 of set number 2| sirmaur
# Processing City Number 31 of set number 2| kununurra
# Processing City Number 32 of set number 2| zhuhai
# Processing City Number 33 of set number 2| saskylakh
# Processing City Number 34 of set number 2| ponta do sol
# Processing City Number 35 of set number 2| dole
# Processing City Number 36 of set number 2| carnarvon
# Processing City Number 37 of set number 2| mahebourg
# Processing City Number 38 of set number 2| nikko
# Processing City Number 39 of set number 2| san cristobal
# Processing City Number 40 of set number 2| jinchang
# Processing City Number 41 of set number 2| salalah
# no city found for this one
# Processing City Number 42 of set number 2| hilo
# Processing City Number 43 of set number 2| hithadhoo
# Processing City Number 44 of set number 2| sosnovo-ozerskoye
# no city found for this one
# no city found for this one
# Processing City Number 45 of set number 2| mataura
# Processing City Number 46 of set number 2| yellowknife
# Processing City Number 47 of set number 2| jaisalmer
# Processing City Number 48 of set number 2| smithers
# Processing City Number 49 of set number 2| gayeri
# Processing City Number 1 of set number 3| lewistown
# Processing City Number 2 of set number 3| georgetown
# Processing City Number 3 of set number 3| joaima
# Processing City Number 4 of set number 3| srednekolymsk
# Processing City Number 5 of set number 3| sola
# Processing City Number 6 of set number 3| port elizabeth
# Processing City Number 7 of set number 3| eganville
# Processing City Number 8 of set number 3| warmbad
# Processing City Number 9 of set number 3| mandalgovi
# Processing City Number 10 of set number 3| zadar
# Processing City Number 11 of set number 3| puerto ayora
# Processing City Number 12 of set number 3| sete lagoas
# Processing City Number 13 of set number 3| snyder
# Processing City Number 14 of set number 3| pringsewu
# Processing City Number 15 of set number 3| innisfail
# no city found for this one
# Processing City Number 16 of set number 3| klaksvik
# no city found for this one
# Processing City Number 17 of set number 3| tautira
# Processing City Number 18 of set number 3| staszow
# Processing City Number 19 of set number 3| port alfred
# Processing City Number 20 of set number 3| hamilton
# Processing City Number 21 of set number 3| aurora
# Processing City Number 22 of set number 3| cabo san lucas
# Processing City Number 23 of set number 3| remontnoye
# Processing City Number 24 of set number 3| nola
# no city found for this one
# Processing City Number 25 of set number 3| odweyne
# Processing City Number 26 of set number 3| tucuma
# no city found for this one
# Processing City Number 27 of set number 3| nanortalik
# Processing City Number 28 of set number 3| newport
# Processing City Number 29 of set number 3| tiksi
# Processing City Number 30 of set number 3| iqaluit
# Processing City Number 31 of set number 3| lebu
# Processing City Number 32 of set number 3| puerto baquerizo moreno
# Processing City Number 33 of set number 3| nanzhang
# Processing City Number 34 of set number 3| caravelas
# Processing City Number 35 of set number 3| berbera
# Processing City Number 36 of set number 3| capaci
# Processing City Number 37 of set number 3| tanabe
# Processing City Number 38 of set number 3| maldonado
# Processing City Number 39 of set number 3| estelle
# Processing City Number 40 of set number 3| reconquista
# Processing City Number 41 of set number 3| russell
# Processing City Number 42 of set number 3| kropotkin
# Processing City Number 43 of set number 3| samana
# Processing City Number 44 of set number 3| geraldton
# Processing City Number 45 of set number 3| pisco
# Processing City Number 46 of set number 3| uglovskoye
# Processing City Number 47 of set number 3| tuktoyaktuk
# Processing City Number 48 of set number 3| alenquer
# no city found for this one
# no city found for this one
# Processing City Number 49 of set number 3| marzuq
# Processing City Number 1 of set number 4| isangel
# Processing City Number 2 of set number 4| aklavik
# Processing City Number 3 of set number 4| neuquen
# Processing City Number 4 of set number 4| cherskiy
# Processing City Number 5 of set number 4| strezhevoy
# Processing City Number 6 of set number 4| grand river south east
# Processing City Number 7 of set number 4| goderich
# Processing City Number 8 of set number 4| coquimbo
# Processing City Number 9 of set number 4| zitsa
# Processing City Number 10 of set number 4| ambilobe
# Processing City Number 11 of set number 4| bambanglipuro
# Processing City Number 12 of set number 4| yulara
# Processing City Number 13 of set number 4| garowe
# Processing City Number 14 of set number 4| neiafu
# Processing City Number 15 of set number 4| gweru
# Processing City Number 16 of set number 4| thompson
# Processing City Number 17 of set number 4| camacha
# Processing City Number 18 of set number 4| saint-pierre
# Processing City Number 19 of set number 4| chadan
# Processing City Number 20 of set number 4| asmara
# Processing City Number 21 of set number 4| havre-saint-pierre
# Processing City Number 22 of set number 4| vuktyl
# Processing City Number 23 of set number 4| chokurdakh
# Processing City Number 24 of set number 4| portland
# Processing City Number 25 of set number 4| hongjiang
# Processing City Number 26 of set number 4| port macquarie
# Processing City Number 27 of set number 4| arraial do cabo
# Processing City Number 28 of set number 4| chuy
# no city found for this one
# Processing City Number 29 of set number 4| bethel
# Processing City Number 30 of set number 4| nikolskoye
# Processing City Number 31 of set number 4| hokitika
# Processing City Number 32 of set number 4| kenai
# no city found for this one
# Processing City Number 33 of set number 4| bambous virieux
# Processing City Number 34 of set number 4| rocha
# Processing City Number 35 of set number 4| raudeberg
# Processing City Number 36 of set number 4| ukiah
# Processing City Number 37 of set number 4| pingzhuang
# Processing City Number 38 of set number 4| kupang
# Processing City Number 39 of set number 4| redlands
# Processing City Number 40 of set number 4| sinnamary
# Processing City Number 41 of set number 4| jalu
# Processing City Number 42 of set number 4| sakaiminato
# Processing City Number 43 of set number 4| victoria
# Processing City Number 44 of set number 4| ust-barguzin
# Processing City Number 45 of set number 4| praia da vitoria
# no city found for this one
# Processing City Number 46 of set number 4| luderitz
# Processing City Number 47 of set number 4| arkhara
# Processing City Number 48 of set number 4| pajapan
# no city found for this one
# Processing City Number 49 of set number 4| cidreira
# Processing City Number 1 of set number 5| damghan
# no city found for this one
# Processing City Number 2 of set number 5| parabel
# Processing City Number 3 of set number 5| soyo
# Processing City Number 4 of set number 5| tuatapere
# Processing City Number 5 of set number 5| sheridan
# Processing City Number 6 of set number 5| belmonte
# Processing City Number 7 of set number 5| paamiut
# Processing City Number 8 of set number 5| kizema
# Processing City Number 9 of set number 5| bulungu
# Processing City Number 10 of set number 5| nome
# Processing City Number 11 of set number 5| shahabad
# Processing City Number 12 of set number 5| yumen
# Processing City Number 13 of set number 5| nishihara
# no city found for this one
# Processing City Number 14 of set number 5| zhigansk
# Processing City Number 15 of set number 5| provideniya
# Processing City Number 16 of set number 5| huesca
# Processing City Number 17 of set number 5| mathbaria
# Processing City Number 18 of set number 5| yerbogachen
# Processing City Number 19 of set number 5| mabaruma
# Processing City Number 20 of set number 5| kahului
# Processing City Number 21 of set number 5| qasigiannguit
# Processing City Number 22 of set number 5| college
# Processing City Number 23 of set number 5| severo-yeniseyskiy
# Processing City Number 24 of set number 5| guerrero negro
# no city found for this one
# Processing City Number 25 of set number 5| ibiapina
# Processing City Number 26 of set number 5| ewa beach
# no city found for this one
# Processing City Number 27 of set number 5| sao filipe
# Processing City Number 28 of set number 5| peniche
# Processing City Number 29 of set number 5| ilulissat
# Processing City Number 30 of set number 5| mount barker
# Processing City Number 31 of set number 5| cartagena
# Processing City Number 32 of set number 5| cap malheureux
# Processing City Number 33 of set number 5| margate
# Processing City Number 34 of set number 5| les cayes
# Processing City Number 35 of set number 5| baghdad
# Processing City Number 36 of set number 5| mandiana
# Processing City Number 37 of set number 5| meredith
# Processing City Number 38 of set number 5| san rafael del sur
# Processing City Number 39 of set number 5| zdanice
# Processing City Number 40 of set number 5| kodinsk
# Processing City Number 41 of set number 5| inuvik
# Processing City Number 42 of set number 5| shchelkun
# Processing City Number 43 of set number 5| zeya
# Processing City Number 44 of set number 5| rundu
# Processing City Number 45 of set number 5| galle
# Processing City Number 46 of set number 5| ahipara
# Processing City Number 47 of set number 5| marawi
# Processing City Number 48 of set number 5| saint-philippe
# Processing City Number 49 of set number 5| westport
# Processing City Number 1 of set number 6| taltal
# Processing City Number 2 of set number 6| urumqi
# no city found for this one
# Processing City Number 3 of set number 6| erenhot
# Processing City Number 4 of set number 6| burnie
# Processing City Number 5 of set number 6| narsaq
# no city found for this one
# Processing City Number 6 of set number 6| darnah
# Processing City Number 7 of set number 6| veraval
# Processing City Number 8 of set number 6| baruun-urt
# Processing City Number 9 of set number 6| husavik
# no city found for this one
# Processing City Number 10 of set number 6| shakawe
# Processing City Number 11 of set number 6| carauari
# Processing City Number 12 of set number 6| tucuman
# Processing City Number 13 of set number 6| lagoa
# Processing City Number 14 of set number 6| najran
# Processing City Number 15 of set number 6| muroto
# Processing City Number 16 of set number 6| nuuk
# no city found for this one
# Processing City Number 17 of set number 6| kibaya
# Processing City Number 18 of set number 6| bengkulu
# Processing City Number 19 of set number 6| kavieng
# Processing City Number 20 of set number 6| boffa
# no city found for this one
# Processing City Number 21 of set number 6| traverse city
# Processing City Number 22 of set number 6| verkhoyansk
# Processing City Number 23 of set number 6| faanui
# Processing City Number 24 of set number 6| plettenberg bay
# Processing City Number 25 of set number 6| igrim
# Processing City Number 26 of set number 6| janossomorja
# Processing City Number 27 of set number 6| novyy urengoy
# Processing City Number 28 of set number 6| kampene
# Processing City Number 29 of set number 6| kodiak
# Processing City Number 30 of set number 6| banjarmasin
# Processing City Number 31 of set number 6| grindavik
# no city found for this one
# Processing City Number 32 of set number 6| pevek
# Processing City Number 33 of set number 6| kruisfontein
# Processing City Number 34 of set number 6| amazar
# Processing City Number 35 of set number 6| knoxville
# Processing City Number 36 of set number 6| kita
# Processing City Number 37 of set number 6| methven
# Processing City Number 38 of set number 6| santa rosa de aguan
# Processing City Number 39 of set number 6| harper
# Processing City Number 40 of set number 6| sao raimundo nonato
# Processing City Number 41 of set number 6| berovo
# Processing City Number 42 of set number 6| fairbanks
# Processing City Number 43 of set number 6| tura
# Processing City Number 44 of set number 6| miyako
# Processing City Number 45 of set number 6| avarua
# Processing City Number 46 of set number 6| ulladulla
# Processing City Number 47 of set number 6| bathsheba
# Processing City Number 48 of set number 6| barela
# Processing City Number 49 of set number 6| muros
# Processing City Number 1 of set number 7| asau
# no city found for this one
# Processing City Number 2 of set number 7| shache
# Processing City Number 3 of set number 7| upernavik
# Processing City Number 4 of set number 7| friesoythe
# Processing City Number 5 of set number 7| havoysund
# Processing City Number 6 of set number 7| evensk
# no city found for this one
# Processing City Number 7 of set number 7| metro
# Processing City Number 8 of set number 7| kaitangata
# Processing City Number 9 of set number 7| sangar
# Processing City Number 10 of set number 7| hami
# Processing City Number 11 of set number 7| northam
# Processing City Number 12 of set number 7| las vegas
# Processing City Number 13 of set number 7| auki
# Processing City Number 14 of set number 7| catuday
# Processing City Number 15 of set number 7| padang
# Processing City Number 16 of set number 7| port lincoln
# Processing City Number 17 of set number 7| souillac
# Processing City Number 18 of set number 7| constitucion
# Processing City Number 19 of set number 7| rock sound
# Processing City Number 20 of set number 7| sorong
# Processing City Number 21 of set number 7| berlevag
# Processing City Number 22 of set number 7| biak
# Processing City Number 23 of set number 7| sur
# Processing City Number 24 of set number 7| richards bay
# Processing City Number 25 of set number 7| vostok
# no city found for this one
# Processing City Number 26 of set number 7| lorengau
# Processing City Number 27 of set number 7| santiago del estero
# Processing City Number 28 of set number 7| hanzhong
# Processing City Number 29 of set number 7| karratha
# Processing City Number 30 of set number 7| araouane
# Processing City Number 31 of set number 7| luanda
# Processing City Number 32 of set number 7| southbridge
# Processing City Number 33 of set number 7| knysna
# Processing City Number 34 of set number 7| byron bay
# Processing City Number 35 of set number 7| narrabri
# Processing City Number 36 of set number 7| port hardy
# Processing City Number 37 of set number 7| zachary
# Processing City Number 38 of set number 7| chaoyang
# Processing City Number 39 of set number 7| point pedro
# Processing City Number 40 of set number 7| nizhniy kuranakh
# Processing City Number 41 of set number 7| mpulungu
# no city found for this one
# no city found for this one
# Processing City Number 42 of set number 7| parana
# Processing City Number 43 of set number 7| kota tinggi
# Processing City Number 44 of set number 7| nelson bay
# Processing City Number 45 of set number 7| san patricio
# Processing City Number 46 of set number 7| goure
# Processing City Number 47 of set number 7| broome
# Processing City Number 48 of set number 7| malanje
# Processing City Number 49 of set number 7| torbay
# no city found for this one
# Processing City Number 1 of set number 8| laranjal paulista
# Processing City Number 2 of set number 8| adamas
# Processing City Number 3 of set number 8| kapoeta
# no city found for this one
# Processing City Number 4 of set number 8| ban dung
# Processing City Number 5 of set number 8| amapa
# Processing City Number 6 of set number 8| sendafa
# Processing City Number 7 of set number 8| mount gambier
# Processing City Number 8 of set number 8| aquiraz
# Processing City Number 9 of set number 8| morant bay
# Processing City Number 10 of set number 8| kaliua
# Processing City Number 11 of set number 8| navalmoral de la mata
# Processing City Number 12 of set number 8| armacao dos buzios
# Processing City Number 13 of set number 8| buala
# no city found for this one
# Processing City Number 14 of set number 8| masalli
# Processing City Number 15 of set number 8| algeciras
# Processing City Number 16 of set number 8| vao
# Processing City Number 17 of set number 8| georgiyevka
# Processing City Number 18 of set number 8| ghazipur
# Processing City Number 19 of set number 8| marsaxlokk
# no city found for this one
# Processing City Number 20 of set number 8| muravlenko
# Processing City Number 21 of set number 8| itaporanga
# no city found for this one
# Processing City Number 22 of set number 8| raton
# Processing City Number 23 of set number 8| novobirilyussy
# Processing City Number 24 of set number 8| abu zabad
# Processing City Number 25 of set number 8| tapiramuta
# Processing City Number 26 of set number 8| kshenskiy
# Processing City Number 27 of set number 8| iranshahr
# Processing City Number 28 of set number 8| pailon
# Processing City Number 29 of set number 8| sept-iles
# Processing City Number 30 of set number 8| nadym
# Processing City Number 31 of set number 8| vila velha
# Processing City Number 32 of set number 8| vaitape
# Processing City Number 33 of set number 8| bonthe
# no city found for this one
# Processing City Number 34 of set number 8| jibuti
# Processing City Number 35 of set number 8| nueva loja
# Processing City Number 36 of set number 8| dingle
# no city found for this one
# Processing City Number 37 of set number 8| sitka
# Processing City Number 38 of set number 8| roebourne
# no city found for this one
# Processing City Number 39 of set number 8| quixeramobim
# no city found for this one
# Processing City Number 40 of set number 8| ust-tsilma
# Processing City Number 41 of set number 8| sala
# Processing City Number 42 of set number 8| pangnirtung
# Processing City Number 43 of set number 8| rabat
# Processing City Number 44 of set number 8| pacific grove
# Processing City Number 45 of set number 8| indramayu
# Processing City Number 46 of set number 8| luganville
# Processing City Number 47 of set number 8| sorland
# Processing City Number 48 of set number 8| mys shmidta
# Processing City Number 49 of set number 8| jeremie
# Processing City Number 1 of set number 9| straza
# Processing City Number 2 of set number 9| sabang
# Processing City Number 3 of set number 9| tessalit
# no city found for this one
# Processing City Number 4 of set number 9| sainte-rose
# Processing City Number 5 of set number 9| fort walton beach
# Processing City Number 6 of set number 9| comodoro rivadavia
# Processing City Number 7 of set number 9| marrakesh
# Processing City Number 8 of set number 9| saint-francois
# no city found for this one
# Processing City Number 9 of set number 9| darhan
# Processing City Number 10 of set number 9| pijino
# no city found for this one
# Processing City Number 11 of set number 9| mandera
# Processing City Number 12 of set number 9| cabedelo
# Processing City Number 13 of set number 9| ferkessedougou
# Processing City Number 14 of set number 9| severo-kurilsk
# Processing City Number 15 of set number 9| ligayan
# Processing City Number 16 of set number 9| omsukchan
# Processing City Number 17 of set number 9| dubbo
# Processing City Number 18 of set number 9| labuhan
# Processing City Number 19 of set number 9| fougamou
# no city found for this one
# Processing City Number 20 of set number 9| namibe
# Processing City Number 21 of set number 9| acarau
# Processing City Number 22 of set number 9| svetlaya
# Processing City Number 23 of set number 9| saint-joseph
# Processing City Number 24 of set number 9| opuwo
# Processing City Number 25 of set number 9| kavaratti
# Processing City Number 26 of set number 9| kaili
# Processing City Number 27 of set number 9| chatra
# Processing City Number 28 of set number 9| nortelandia
# Processing City Number 29 of set number 9| niteroi
# Processing City Number 30 of set number 9| avinurme
# Processing City Number 31 of set number 9| kamenka
# Processing City Number 32 of set number 9| bethanien
# Processing City Number 33 of set number 9| crixas
# no city found for this one
# Processing City Number 34 of set number 9| nabire
# Processing City Number 35 of set number 9| providencia
# Processing City Number 36 of set number 9| kpandu
# Processing City Number 37 of set number 9| guarapari
# Processing City Number 38 of set number 9| jumla
# Processing City Number 39 of set number 9| makurdi
# Processing City Number 40 of set number 9| hirara
# Processing City Number 41 of set number 9| kembe
# Processing City Number 42 of set number 9| bilibino
# Processing City Number 43 of set number 9| mayo
# Processing City Number 44 of set number 9| dudinka
# Processing City Number 45 of set number 9| rockhampton
# Processing City Number 46 of set number 9| krouson
# Processing City Number 47 of set number 9| ozernovskiy
# no city found for this one
# Processing City Number 48 of set number 9| madaba
# Processing City Number 49 of set number 9| lata
# Processing City Number 1 of set number 10| esil
# Processing City Number 2 of set number 10| poum
# Processing City Number 3 of set number 10| ixtapa
# Processing City Number 4 of set number 10| wilmington
# Processing City Number 5 of set number 10| dunedin
# Processing City Number 6 of set number 10| zandvoort
# Processing City Number 7 of set number 10| gidam
# Processing City Number 8 of set number 10| katherine
# Processing City Number 9 of set number 10| bose
# Processing City Number 10 of set number 10| honiara
# Processing City Number 11 of set number 10| buin
# Processing City Number 12 of set number 10| abilene
# Processing City Number 13 of set number 10| banda aceh
# Processing City Number 14 of set number 10| ningxiang
# Processing City Number 15 of set number 10| livingstone
# Processing City Number 16 of set number 10| naze
# Processing City Number 17 of set number 10| tsiroanomandidy
# Processing City Number 18 of set number 10| akdepe
# Processing City Number 19 of set number 10| visnes
# Processing City Number 20 of set number 10| manicore
# Processing City Number 21 of set number 10| maragogi
# Processing City Number 22 of set number 10| palmer
# Processing City Number 23 of set number 10| batagay
# Processing City Number 24 of set number 10| kalemie
# no city found for this one
# Processing City Number 25 of set number 10| tukrah
# Processing City Number 26 of set number 10| bereda
# Processing City Number 27 of set number 10| oriximina
# Processing City Number 28 of set number 10| bom jesus
# Processing City Number 29 of set number 10| urzhum
# Processing City Number 30 of set number 10| podporozhye
# Processing City Number 31 of set number 10| malatya
# Processing City Number 32 of set number 10| erzin
# Processing City Number 33 of set number 10| chany
# Processing City Number 34 of set number 10| chaohu
# Processing City Number 35 of set number 10| shitkino
# Processing City Number 36 of set number 10| alice springs
# Processing City Number 37 of set number 10| penzance
# Processing City Number 38 of set number 10| nichelino
# Processing City Number 39 of set number 10| porto novo
# Processing City Number 40 of set number 10| nyircsaholy
# no city found for this one
# Processing City Number 41 of set number 10| lompoc
# Processing City Number 42 of set number 10| komsomolskiy
# Processing City Number 43 of set number 10| madison heights
# Processing City Number 44 of set number 10| marivan
# Processing City Number 45 of set number 10| ostrovnoy
# Processing City Number 46 of set number 10| ballina
# Processing City Number 47 of set number 10| fairview
# Processing City Number 48 of set number 10| ola
# Processing City Number 49 of set number 10| namatanai
# Processing City Number 1 of set number 11| adrar
# Processing City Number 2 of set number 11| bitkine
# Processing City Number 3 of set number 11| agirish
# Processing City Number 4 of set number 11| ambon
# Processing City Number 5 of set number 11| kristiinankaupunki
# Processing City Number 6 of set number 11| matagami
# Processing City Number 7 of set number 11| touros
# Processing City Number 8 of set number 11| coihaique
# Processing City Number 9 of set number 11| quelimane
# no city found for this one
# Processing City Number 10 of set number 11| heinola
# Processing City Number 11 of set number 11| wattegama
# Processing City Number 12 of set number 11| pasni
# Processing City Number 13 of set number 11| timra
# Processing City Number 14 of set number 11| cockburn town
# Processing City Number 15 of set number 11| eirunepe
# Processing City Number 16 of set number 11| moissala
# Processing City Number 17 of set number 11| jimenez
# Processing City Number 18 of set number 11| guanare
# Processing City Number 19 of set number 11| calabozo
# Processing City Number 20 of set number 11| hailar
# Processing City Number 21 of set number 11| toucheng
# Processing City Number 22 of set number 11| nha trang
# no city found for this one
# Processing City Number 23 of set number 11| kungalv
# Processing City Number 24 of set number 11| moree
# Processing City Number 25 of set number 11| bay roberts
# Processing City Number 26 of set number 11| kutum
# Processing City Number 27 of set number 11| arlit
# Processing City Number 28 of set number 11| petropavlovsk-kamchatskiy
# Processing City Number 29 of set number 11| leua
# Processing City Number 30 of set number 11| cervo
# Processing City Number 31 of set number 11| havelock
# no city found for this one
# no city found for this one
# Processing City Number 32 of set number 11| bogorodskoye
# Processing City Number 33 of set number 11| sulat
# Processing City Number 34 of set number 11| tall kayf
# Processing City Number 35 of set number 11| balotra
# Processing City Number 36 of set number 11| shimoda
# no city found for this one
# Processing City Number 37 of set number 11| itapecerica
# Processing City Number 38 of set number 11| yanaul
# Processing City Number 39 of set number 11| avera
# Processing City Number 40 of set number 11| tortoli
# Processing City Number 41 of set number 11| hovd
# Processing City Number 42 of set number 11| lima
# Processing City Number 43 of set number 11| kemi
# Processing City Number 44 of set number 11| okhotsk
# no city found for this one
# Processing City Number 45 of set number 11| dhemaji
# Processing City Number 46 of set number 11| tyrma
# no city found for this one
# Processing City Number 47 of set number 11| gamba
# Processing City Number 48 of set number 11| tiruchchendur
# no city found for this one
# Processing City Number 49 of set number 11| deputatskiy
# Processing City Number 1 of set number 12| juba
# Processing City Number 2 of set number 12| kaeo
# Processing City Number 3 of set number 12| barra patuca
# Processing City Number 4 of set number 12| ormara
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city":city_two,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Humidity":humidities,
    "Cloudiness":cloudinesses,
    "Wind Speed":wind_speeds,
    "Country":countries,
    "Date":dates
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#          city      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  talcahuano -36.7167  -73.1167     66.20        68           0       11.50
# 1       bluff -46.6000  168.3333     54.68        91          14        6.96
# 2      albany  42.6001  -73.9662     21.99        50          99        1.01
# 3    katsuura  35.1333  140.3000     61.00        72          75       21.85
# 4    saldanha -33.0117   17.9442     84.20        30           0       17.27
#
#   Country        Date
# 0      CL  1612197630
# 1      NZ  1612197636
# 2      US  1612197636
# 3      JP  1612197636
# 4      ZA  1612197636

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum_one_hund = weather_df[weather_df['Humidity'].astype('int64') >= 100]
hum_one_hund
# Out:
#             city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 8          airai  -8.9266  125.4092     61.59       100          99
# 60    hambantota   6.1241   81.1185     77.00       100           0
# 62         vaini -21.2000 -175.2000     75.20       100          90
# 79     kununurra -15.7667  128.7333     78.80       100          40
# 98     lewistown  40.5992  -77.5714     28.40       100          90
# 120   remontnoye  46.5614   43.6501     39.00       100          90
# 274  banjarmasin  -3.3244  114.5910     77.00       100          75
# 289       avarua -21.2078 -159.7750     75.20       100          82
# 290    ulladulla -35.3500  150.4667     62.60       100          90
# 434         mayo  38.8876  -76.5119     34.00       100          90
# 477     penzance  50.1186   -5.5371     50.00       100          90
# 480  nyircsaholy  47.9038   22.3363     35.01       100          90
# 500    wattegama   6.7989   81.4808     77.00       100           0
# 520     havelock  34.8791  -76.9013     39.00       100          90
#
#      Wind Speed Country        Date
# 8          2.62      TL  1612197637
# 60         8.05      LK  1612197643
# 62        28.77      TO  1612197643
# 79         3.44      AU  1612197635
# 98        10.36      US  1612197648
# 120       20.13      RU  1612197650
# 274        3.44      ID  1612197669
# 289        1.14      CK  1612197671
# 290       12.66      AU  1612197671
# 434       11.50      US  1612197691
# 477        8.05      GB  1612197696
# 480        2.30      HU  1612197696
# 500        8.05      LK  1612197698
# 520       13.80      US  1612197701

# %%
#  Get the indices of cities that have humidity over 100%.
hund_hum_indexes = [hum_one_hund[hum_one_hund['Humidity']==100].index.values]
hund_hum_indexes
# Out:
# [array([  8,  60,  62,  79,  98, 120, 274, 289, 290, 434, 477, 480, 500,
#         520], dtype=int64)]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cleaned_df = weather_df[weather_df['Humidity'].astype('int64') != 100]
cleaned_df.head()
#len(cleaned_df.index)
# Out:
#          city      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  talcahuano -36.7167  -73.1167     66.20        68           0       11.50
# 1       bluff -46.6000  168.3333     54.68        91          14        6.96
# 2      albany  42.6001  -73.9662     21.99        50          99        1.01
# 3    katsuura  35.1333  140.3000     61.00        72          75       21.85
# 4    saldanha -33.0117   17.9442     84.20        30           0       17.27
#
#   Country        Date
# 0      CL  1612197630
# 1      NZ  1612197636
# 2      US  1612197636
# 3      JP  1612197636
# 4      ZA  1612197636

# %%
def plot_scat(y,y_label):
    lat_y = plt.scatter(cleaned_df['Lat'],cleaned_df[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(cleaned_df[y])-20,max(cleaned_df[y])+20)
    plt.grid()
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp = plot_scat(y='Max Temp',y_label='Max Temperature (F)')
lat_temp

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_humidity = plot_scat(y='Humidity',y_label='Humidity(%)')
lat_humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloud = plot_scat(y='Cloudiness',y_label='Cloudiness(%)')
lat_cloud

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_wind = plot_scat(y='Wind Speed',y_label='Wind Speed (mph)')
lat_wind

# %% [markdown]
# ## Linear Regression

# %%
north_hem = cleaned_df[cleaned_df['Lat'] >= 0]
south_hem = cleaned_df[cleaned_df['Lat'] < 0]

def plot_scat_north(y,y_label):
    lat_y = plt.scatter(north_hem['Lat'],north_hem[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(north_hem[y])-20,max(north_hem[y])+20)
    plt.grid()
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))
    
def plot_scat_south(y,y_label):
    lat_y = plt.scatter(south_hem['Lat'],south_hem[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(south_hem[y])-20,max(south_hem[y])+20)
    plt.grid()
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_temp_north = plot_scat_north(y='Max Temp',y_label='Max Temperature (F)')
lat_temp_north

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_temp_south = plot_scat_south(y='Max Temp',y_label='Max Temperature (F)')
lat_temp_south

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
