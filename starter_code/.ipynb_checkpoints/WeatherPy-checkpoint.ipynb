# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy import stats
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key
temp_units = 'imperial'

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Set URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# City and Set Number
city_num = 0
set_num = 1
# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if city_num > 48:
            city_num = 1
            set_num += 1
            city_two.append(city)
        else:
            city_num += 1
            city_two.append(city)
        print(f"Processing City Number {city_num} of set number {set_num}| {city}")
    except:
        print('no city found for this one')
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# no city found for this one
# Processing City Number 1 of set number 1| haines junction
# Processing City Number 2 of set number 1| tuktoyaktuk
# Processing City Number 3 of set number 1| houston
# Processing City Number 4 of set number 1| sackville
# Processing City Number 5 of set number 1| carnarvon
# no city found for this one
# Processing City Number 6 of set number 1| busselton
# Processing City Number 7 of set number 1| arraial do cabo
# Processing City Number 8 of set number 1| burnie
# Processing City Number 9 of set number 1| cape town
# Processing City Number 10 of set number 1| barrow
# Processing City Number 11 of set number 1| hobyo
# Processing City Number 12 of set number 1| hilo
# Processing City Number 13 of set number 1| hervey bay
# Processing City Number 14 of set number 1| lucapa
# Processing City Number 15 of set number 1| souillac
# Processing City Number 16 of set number 1| boyolangu
# Processing City Number 17 of set number 1| cidreira
# Processing City Number 18 of set number 1| bowen
# Processing City Number 19 of set number 1| puerto ayora
# Processing City Number 20 of set number 1| naze
# Processing City Number 21 of set number 1| rikitea
# Processing City Number 22 of set number 1| mahebourg
# Processing City Number 23 of set number 1| vaini
# Processing City Number 24 of set number 1| sitka
# Processing City Number 25 of set number 1| qaanaaq
# Processing City Number 26 of set number 1| hermanus
# Processing City Number 27 of set number 1| loa janan
# Processing City Number 28 of set number 1| coquimbo
# Processing City Number 29 of set number 1| takoradi
# Processing City Number 30 of set number 1| kaitangata
# Processing City Number 31 of set number 1| georgetown
# Processing City Number 32 of set number 1| tadine
# Processing City Number 33 of set number 1| santa ines
# Processing City Number 34 of set number 1| touros
# Processing City Number 35 of set number 1| bathsheba
# Processing City Number 36 of set number 1| berlevag
# Processing City Number 37 of set number 1| torbay
# Processing City Number 38 of set number 1| marzuq
# no city found for this one
# Processing City Number 39 of set number 1| saldanha
# Processing City Number 40 of set number 1| avarua
# Processing City Number 41 of set number 1| sao joao da barra
# Processing City Number 42 of set number 1| dikson
# Processing City Number 43 of set number 1| agadez
# Processing City Number 44 of set number 1| jiwani
# Processing City Number 45 of set number 1| morondava
# Processing City Number 46 of set number 1| jamestown
# Processing City Number 47 of set number 1| poum
# Processing City Number 48 of set number 1| mezen
# Processing City Number 49 of set number 1| castro
# Processing City Number 1 of set number 2| ushuaia
# Processing City Number 2 of set number 2| antofagasta
# Processing City Number 3 of set number 2| mapiri
# Processing City Number 4 of set number 2| labuhan
# Processing City Number 5 of set number 2| bambous virieux
# Processing City Number 6 of set number 2| saint-georges
# Processing City Number 7 of set number 2| ilebo
# no city found for this one
# Processing City Number 8 of set number 2| abha
# Processing City Number 9 of set number 2| bredasdorp
# Processing City Number 10 of set number 2| airai
# Processing City Number 11 of set number 2| albany
# Processing City Number 12 of set number 2| kuryk
# Processing City Number 13 of set number 2| san ignacio
# Processing City Number 14 of set number 2| khatanga
# Processing City Number 15 of set number 2| port blair
# Processing City Number 16 of set number 2| kapaa
# Processing City Number 17 of set number 2| saint-philippe
# Processing City Number 18 of set number 2| butaritari
# Processing City Number 19 of set number 2| mumias
# Processing City Number 20 of set number 2| hobart
# Processing City Number 21 of set number 2| saskylakh
# Processing City Number 22 of set number 2| flinders
# Processing City Number 23 of set number 2| padang
# Processing City Number 24 of set number 2| krasnyy chikoy
# Processing City Number 25 of set number 2| ribeira grande
# Processing City Number 26 of set number 2| isangel
# Processing City Number 27 of set number 2| nakambala
# Processing City Number 28 of set number 2| kuznechnoye
# Processing City Number 29 of set number 2| eyl
# Processing City Number 30 of set number 2| sayyan
# Processing City Number 31 of set number 2| inhambane
# Processing City Number 32 of set number 2| mataura
# Processing City Number 33 of set number 2| zaysan
# Processing City Number 34 of set number 2| mount gambier
# Processing City Number 35 of set number 2| macusani
# no city found for this one
# no city found for this one
# Processing City Number 36 of set number 2| grand river south east
# Processing City Number 37 of set number 2| tiksi
# Processing City Number 38 of set number 2| luebo
# no city found for this one
# Processing City Number 39 of set number 2| new norfolk
# no city found for this one
# Processing City Number 40 of set number 2| severo-kurilsk
# Processing City Number 41 of set number 2| ayr
# Processing City Number 42 of set number 2| balezino
# no city found for this one
# Processing City Number 43 of set number 2| victoria
# no city found for this one
# Processing City Number 44 of set number 2| grindavik
# Processing City Number 45 of set number 2| starogard gdanski
# Processing City Number 46 of set number 2| ancud
# Processing City Number 47 of set number 2| aklavik
# Processing City Number 48 of set number 2| yellowknife
# Processing City Number 49 of set number 2| hithadhoo
# Processing City Number 1 of set number 3| laje
# Processing City Number 2 of set number 3| guerrero negro
# Processing City Number 3 of set number 3| codrington
# Processing City Number 4 of set number 3| iwanai
# Processing City Number 5 of set number 3| kudahuvadhoo
# Processing City Number 6 of set number 3| ondangwa
# Processing City Number 7 of set number 3| dunedin
# Processing City Number 8 of set number 3| port alfred
# Processing City Number 9 of set number 3| kizner
# Processing City Number 10 of set number 3| saint-joseph
# Processing City Number 11 of set number 3| ilulissat
# Processing City Number 12 of set number 3| narsaq
# Processing City Number 13 of set number 3| jasper
# Processing City Number 14 of set number 3| assiniboia
# Processing City Number 15 of set number 3| foix
# no city found for this one
# Processing City Number 16 of set number 3| kahului
# Processing City Number 17 of set number 3| katsuura
# Processing City Number 18 of set number 3| vitim
# Processing City Number 19 of set number 3| ust-maya
# Processing City Number 20 of set number 3| cayenne
# Processing City Number 21 of set number 3| kalianget
# no city found for this one
# Processing City Number 22 of set number 3| port elizabeth
# Processing City Number 23 of set number 3| shubarshi
# Processing City Number 24 of set number 3| upernavik
# Processing City Number 25 of set number 3| oistins
# Processing City Number 26 of set number 3| fortuna
# Processing City Number 27 of set number 3| constitucion
# Processing City Number 28 of set number 3| mys shmidta
# Processing City Number 29 of set number 3| hofn
# Processing City Number 30 of set number 3| kamenka
# Processing City Number 31 of set number 3| port lincoln
# Processing City Number 32 of set number 3| ndele
# Processing City Number 25 of set number 6| itarema
# Processing City Number 26 of set number 6| lazi
# Processing City Number 27 of set number 6| pori
# Processing City Number 28 of set number 6| grand-santi
# Processing City Number 29 of set number 6| kaeo
# Processing City Number 30 of set number 6| dafeng
# no city found for this one
# Processing City Number 31 of set number 6| andenes
# Processing City Number 32 of set number 6| sola
# Processing City Number 33 of set number 6| shihezi
# Processing City Number 34 of set number 6| westport
# Processing City Number 35 of set number 6| hargeysa
# Processing City Number 36 of set number 6| mar del plata
# Processing City Number 37 of set number 6| samarai
# Processing City Number 38 of set number 6| esik
# Processing City Number 39 of set number 6| port-cartier
# Processing City Number 40 of set number 6| sampit
# no city found for this one
# Processing City Number 41 of set number 6| port augusta
# Processing City Number 42 of set number 6| waipawa
# Processing City Number 43 of set number 6| avera
# no city found for this one
# Processing City Number 44 of set number 6| dali
# Processing City Number 45 of set number 6| bambanglipuro
# Processing City Number 46 of set number 6| aztec
# Processing City Number 47 of set number 6| merzifon
# Processing City Number 48 of set number 6| nantucket
# Processing City Number 49 of set number 6| korla
# Processing City Number 1 of set number 7| srednekolymsk
# Processing City Number 2 of set number 7| namatanai
# Processing City Number 3 of set number 7| hami
# Processing City Number 4 of set number 7| kaduqli
# Processing City Number 5 of set number 7| lavrentiya
# Processing City Number 6 of set number 7| bobon
# Processing City Number 7 of set number 7| bethel
# Processing City Number 8 of set number 7| victor harbor
# no city found for this one
# Processing City Number 9 of set number 7| qui nhon
# Processing City Number 10 of set number 7| hirara
# Processing City Number 11 of set number 7| krishnarajasagara
# Processing City Number 12 of set number 7| nacimiento
# Processing City Number 13 of set number 7| petropavlovsk-kamchatskiy
# no city found for this one
# Processing City Number 14 of set number 7| pangnirtung
# Processing City Number 15 of set number 7| iberia
# Processing City Number 16 of set number 7| oxapampa
# Processing City Number 17 of set number 7| kodiak
# Processing City Number 18 of set number 7| qaqortoq
# Processing City Number 19 of set number 7| puerto del rosario
# Processing City Number 20 of set number 7| vostok
# Processing City Number 21 of set number 7| karratha
# Processing City Number 22 of set number 7| beidao
# Processing City Number 23 of set number 7| riyadh
# Processing City Number 24 of set number 7| kiama
# Processing City Number 25 of set number 7| meadow lake
# no city found for this one
# Processing City Number 26 of set number 7| kichera
# no city found for this one
# Processing City Number 27 of set number 7| bom jesus
# Processing City Number 28 of set number 7| banda aceh
# Processing City Number 29 of set number 7| college
# Processing City Number 30 of set number 7| holland
# no city found for this one
# Processing City Number 31 of set number 7| grand gaube
# Processing City Number 32 of set number 7| seddon
# Processing City Number 33 of set number 7| boguchany
# Processing City Number 34 of set number 7| tilichiki
# Processing City Number 35 of set number 7| suntar
# Processing City Number 36 of set number 7| coihaique
# no city found for this one
# Processing City Number 37 of set number 7| pychas
# Processing City Number 38 of set number 7| aswan
# no city found for this one
# Processing City Number 39 of set number 7| cradock
# Processing City Number 40 of set number 7| satao
# no city found for this one
# Processing City Number 41 of set number 7| san patricio
# Processing City Number 42 of set number 7| rio cauto
# Processing City Number 43 of set number 7| brownsville
# Processing City Number 44 of set number 7| zyryanka
# Processing City Number 45 of set number 7| meulaboh
# Processing City Number 46 of set number 7| jabinyanah
# Processing City Number 47 of set number 7| nurota
# Processing City Number 48 of set number 7| save
# Processing City Number 49 of set number 7| eloy
# Processing City Number 1 of set number 8| singaraja
# Processing City Number 2 of set number 8| rexburg
# Processing City Number 3 of set number 8| kuldur
# Processing City Number 4 of set number 8| marang
# Processing City Number 5 of set number 8| creel
# Processing City Number 6 of set number 8| kangshan
# Processing City Number 7 of set number 8| narrabri
# Processing City Number 8 of set number 8| santo andre
# Processing City Number 9 of set number 8| fairbanks
# Processing City Number 10 of set number 8| oksfjord
# Processing City Number 11 of set number 8| nizamabad
# Processing City Number 12 of set number 8| kiomboi
# Processing City Number 13 of set number 8| slubice
# Processing City Number 14 of set number 8| metkovic
# no city found for this one
# Processing City Number 15 of set number 8| vila velha
# Processing City Number 16 of set number 8| tessalit
# Processing City Number 17 of set number 8| lask
# Processing City Number 18 of set number 8| laranjeiras do sul
# Processing City Number 19 of set number 8| bontang
# Processing City Number 20 of set number 8| sistranda
# Processing City Number 21 of set number 8| aleksandrovskoye
# Processing City Number 22 of set number 8| pingliang
# no city found for this one
# Processing City Number 23 of set number 8| taltal
# Processing City Number 24 of set number 8| kharp
# Processing City Number 25 of set number 8| faya
# no city found for this one
# Processing City Number 26 of set number 8| tucuma
# Processing City Number 27 of set number 8| monrovia
# Processing City Number 28 of set number 8| strazske
# Processing City Number 29 of set number 8| kishtwar
# Processing City Number 30 of set number 8| honiara
# Processing City Number 31 of set number 8| mamlyutka
# Processing City Number 32 of set number 8| altay
# Processing City Number 33 of set number 8| chirawa
# Processing City Number 34 of set number 8| mehriz
# Processing City Number 35 of set number 8| bardiyah
# Processing City Number 36 of set number 8| fort abbas
# Processing City Number 37 of set number 8| ilo
# Processing City Number 38 of set number 8| rosetta
# Processing City Number 39 of set number 8| wilmington
# Processing City Number 40 of set number 8| petrozavodsk
# Processing City Number 41 of set number 8| marsabit
# Processing City Number 42 of set number 8| uray
# Processing City Number 43 of set number 8| sangin
# Processing City Number 44 of set number 8| dingle
# Processing City Number 45 of set number 8| tuy hoa
# Processing City Number 46 of set number 8| yenagoa
# Processing City Number 47 of set number 8| saint-augustin
# Processing City Number 48 of set number 8| rorvik
# no city found for this one
# Processing City Number 49 of set number 8| cedar city
# Processing City Number 1 of set number 9| arlit
# Processing City Number 2 of set number 9| broome
# Processing City Number 3 of set number 9| itirucu
# Processing City Number 4 of set number 9| kavaratti
# Processing City Number 5 of set number 9| agadir
# Processing City Number 6 of set number 9| goundam
# Processing City Number 7 of set number 9| cascais
# Processing City Number 8 of set number 9| tura
# Processing City Number 9 of set number 9| cockburn town
# no city found for this one
# Processing City Number 10 of set number 9| algiers
# Processing City Number 11 of set number 9| abu samrah
# Processing City Number 12 of set number 9| chegdomyn
# Processing City Number 13 of set number 9| saint-francois
# Processing City Number 14 of set number 9| san ramon de la nueva oran
# Processing City Number 15 of set number 9| ust-tsilma
# Processing City Number 16 of set number 9| shaunavon
# Processing City Number 17 of set number 9| gravdal
# no city found for this one
# Processing City Number 18 of set number 9| noumea
# Processing City Number 19 of set number 9| wajima
# Processing City Number 20 of set number 9| pemba
# Processing City Number 21 of set number 9| ayan
# no city found for this one
# Processing City Number 22 of set number 9| lashio
# Processing City Number 23 of set number 9| dakar
# Processing City Number 24 of set number 9| bac lieu
# Processing City Number 25 of set number 9| batagay-alyta
# Processing City Number 26 of set number 9| guanare
# Processing City Number 27 of set number 9| sulangan
# Processing City Number 28 of set number 9| northam
# Processing City Number 29 of set number 9| lorengau
# Processing City Number 30 of set number 9| matamba
# Processing City Number 31 of set number 9| eidfjord
# Processing City Number 32 of set number 9| morant bay
# Processing City Number 33 of set number 9| uvat
# Processing City Number 34 of set number 9| salinas
# Processing City Number 35 of set number 9| adrar
# Processing City Number 36 of set number 9| kalmunai
# Processing City Number 37 of set number 9| deputatskiy
# Processing City Number 38 of set number 9| semirom
# Processing City Number 39 of set number 9| polur
# Processing City Number 40 of set number 9| chicama
# Processing City Number 41 of set number 9| dogondoutchi
# Processing City Number 42 of set number 9| vila do maio
# Processing City Number 43 of set number 9| klaksvik
# Processing City Number 44 of set number 9| chunskiy
# Processing City Number 45 of set number 9| sibolga
# Processing City Number 46 of set number 9| clifton springs
# Processing City Number 47 of set number 9| bonfim
# Processing City Number 48 of set number 9| bonavista
# Processing City Number 49 of set number 9| santa rosa
# Processing City Number 1 of set number 10| sao filipe
# Processing City Number 2 of set number 10| sinnamary
# Processing City Number 3 of set number 10| anamur
# Processing City Number 4 of set number 10| sobolevo
# Processing City Number 5 of set number 10| luanda
# Processing City Number 6 of set number 10| leopold
# Processing City Number 7 of set number 10| cherskiy
# Processing City Number 8 of set number 10| pitimbu
# Processing City Number 9 of set number 10| kavieng
# Processing City Number 10 of set number 10| rocha
# Processing City Number 11 of set number 10| birin
# Processing City Number 12 of set number 10| lichinga
# Processing City Number 13 of set number 10| najran
# Processing City Number 14 of set number 10| lahijan
# Processing City Number 15 of set number 10| omboue
# Processing City Number 16 of set number 10| gornopravdinsk
# no city found for this one
# Processing City Number 17 of set number 10| andover
# Processing City Number 18 of set number 10| payo
# no city found for this one
# Processing City Number 19 of set number 10| libreville
# Processing City Number 20 of set number 10| alekseyevsk
# Processing City Number 21 of set number 10| maragogi
# Processing City Number 22 of set number 10| alexandria
# no city found for this one
# Processing City Number 23 of set number 10| palana
# Processing City Number 24 of set number 10| tocopilla
# Processing City Number 25 of set number 10| taoudenni
# Processing City Number 26 of set number 10| vanimo
# Processing City Number 27 of set number 10| altayskoye
# Processing City Number 28 of set number 10| prince george
# Processing City Number 29 of set number 10| mandera
# Processing City Number 30 of set number 10| angoche
# Processing City Number 31 of set number 10| pojejena
# Processing City Number 32 of set number 10| susanville
# no city found for this one
# Processing City Number 33 of set number 10| urumqi
# Processing City Number 34 of set number 10| kenora
# no city found for this one
# Processing City Number 35 of set number 10| asosa
# Processing City Number 36 of set number 10| svetlogorsk
# Processing City Number 37 of set number 10| savonlinna
# Processing City Number 38 of set number 10| valparaiso
# Processing City Number 39 of set number 10| ostrov
# no city found for this one
# Processing City Number 40 of set number 10| moussoro
# Processing City Number 41 of set number 10| beloha
# Processing City Number 42 of set number 10| baker city
# no city found for this one
# Processing City Number 43 of set number 10| wufeng
# no city found for this one
# Processing City Number 44 of set number 10| tateyama
# Processing City Number 45 of set number 10| zhezkazgan
# Processing City Number 46 of set number 10| portland
# Processing City Number 47 of set number 10| siilinjarvi
# Processing City Number 48 of set number 10| rio gallegos
# no city found for this one
# Processing City Number 49 of set number 10| paducah
# Processing City Number 1 of set number 11| kyzyl-suu
# Processing City Number 2 of set number 11| anloga
# Processing City Number 3 of set number 11| missoula
# Processing City Number 4 of set number 11| kupang
# Processing City Number 5 of set number 11| coruripe
# Processing City Number 6 of set number 11| mackay
# Processing City Number 7 of set number 11| guatire
# Processing City Number 8 of set number 11| amot
# Processing City Number 9 of set number 11| komsomolskiy
# Processing City Number 10 of set number 11| belyy yar
# Processing City Number 11 of set number 11| tokmak
# no city found for this one
# no city found for this one
# no city found for this one
# Processing City Number 12 of set number 11| grants
# no city found for this one
# Processing City Number 13 of set number 11| husavik
# Processing City Number 14 of set number 11| pozzallo
# Processing City Number 15 of set number 11| sur
# Processing City Number 16 of set number 11| impfondo
# Processing City Number 17 of set number 11| inuvik
# Processing City Number 18 of set number 11| forbes
# no city found for this one
# Processing City Number 19 of set number 11| chimoio
# Processing City Number 20 of set number 11| quelimane
# Processing City Number 21 of set number 11| waverly
# Processing City Number 22 of set number 11| koutsouras
# Processing City Number 23 of set number 11| hovd
# Processing City Number 24 of set number 11| warrington
# Processing City Number 25 of set number 11| san quintin
# Processing City Number 26 of set number 11| krasnoselkup
# Processing City Number 27 of set number 11| gravelbourg
# Processing City Number 28 of set number 11| nemuro
# Processing City Number 29 of set number 11| nortelandia
# Processing City Number 30 of set number 11| oranjemund
# Processing City Number 31 of set number 11| mariental
# Processing City Number 32 of set number 11| luba
# no city found for this one
# Processing City Number 33 of set number 11| lata
# Processing City Number 34 of set number 11| chingirlau
# Processing City Number 35 of set number 11| havelock
# Processing City Number 36 of set number 11| ostrovnoy
# Processing City Number 37 of set number 11| ilhabela
# Processing City Number 38 of set number 11| high level
# Processing City Number 39 of set number 11| rawah
# Processing City Number 40 of set number 11| pasinler
# Processing City Number 41 of set number 11| kastamonu
# no city found for this one
# Processing City Number 42 of set number 11| pasighat
# Processing City Number 43 of set number 11| santa maria
# no city found for this one
# Processing City Number 44 of set number 11| nyurba
# Processing City Number 45 of set number 11| yanam
# Processing City Number 46 of set number 11| morro bay
# no city found for this one
# Processing City Number 47 of set number 11| mabaruma
# no city found for this one
# Processing City Number 48 of set number 11| asau
# Processing City Number 49 of set number 11| harper
# Processing City Number 1 of set number 12| barabai
# Processing City Number 2 of set number 12| punta gorda
# Processing City Number 3 of set number 12| banfora
# Processing City Number 4 of set number 12| zhanaozen
# Processing City Number 5 of set number 12| menongue
# Processing City Number 6 of set number 12| cayhagan
# Processing City Number 7 of set number 12| ozernovskiy
# Processing City Number 8 of set number 12| matara
# Processing City Number 9 of set number 12| kungurtug
# no city found for this one
# Processing City Number 10 of set number 12| xuanzhou
# Processing City Number 11 of set number 12| kimbe
# Processing City Number 12 of set number 12| alice springs
# no city found for this one
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city":city_two,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Humidity":humidities,
    "Cloudiness":cloudinesses,
    "Wind Speed":wind_speeds,
    "Country":countries,
    "Date":dates
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#               city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  haines junction  59.2286 -135.4441      17.6        57          90
# 1      tuktoyaktuk  69.4541 -133.0374     -20.2        76          75
# 2          houston  29.7633  -95.3633      57.0        43           1
# 3        sackville  45.9188  -64.3846      32.0        74          98
# 4        carnarvon -24.8667  113.6333      86.0        58          90
#
#    Wind Speed Country        Date
# 0       14.97      US  1612202445
# 1        5.75      CA  1612202445
# 2       10.36      US  1612202385
# 3        6.91      CA  1612202445
# 4       19.57      AU  1612202445

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum_one_hund = weather_df[weather_df['Humidity'].astype('int64') >= 100]
hum_one_hund
# Out:
#             city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 58         airai  -8.9266  125.4092     61.43       100          99
# 182    killybegs  54.6333   -8.4500     42.01       100          90
# 198        alofi -19.0595 -169.9187     75.20       100          90
# 244  porto santo  41.1496   -8.6110     55.40       100          75
# 292    nantucket  41.2835  -70.0995     36.00       100          90
# 398      cascais  38.6979   -9.4215     61.00       100          90
# 446      leopold -38.1833  144.4667     53.01       100          75
# 452     lichinga -13.3128   35.2406     64.40       100          75
# 484     tateyama  34.9833  139.8667     62.01       100          98
# 522         lata  40.1629   -8.3327     57.99       100          94
#
#      Wind Speed Country        Date
# 58         2.62      TL  1612202456
# 182       11.50      IE  1612202477
# 198        4.61      NU  1612202481
# 244       18.41      PT  1612202488
# 292       23.02      US  1612202496
# 398        5.75      PT  1612202217
# 446        9.22      AU  1612202517
# 452        0.81      MZ  1612202518
# 484       11.99      JP  1612202523
# 522       14.00      PT  1612202528

# %%
#  Get the indices of cities that have humidity over 100%.
hund_hum_indexes = [hum_one_hund[hum_one_hund['Humidity']==100].index.values]
hund_hum_indexes
# Out:
# [array([ 58, 182, 198, 244, 292, 398, 446, 452, 484, 522], dtype=int64)]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cleaned_df = weather_df[weather_df['Humidity'].astype('int64') != 100]
cleaned_df.head()
#len(cleaned_df.index)
# Out:
#               city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  haines junction  59.2286 -135.4441      17.6        57          90
# 1      tuktoyaktuk  69.4541 -133.0374     -20.2        76          75
# 2          houston  29.7633  -95.3633      57.0        43           1
# 3        sackville  45.9188  -64.3846      32.0        74          98
# 4        carnarvon -24.8667  113.6333      86.0        58          90
#
#    Wind Speed Country        Date
# 0       14.97      US  1612202445
# 1        5.75      CA  1612202445
# 2       10.36      US  1612202385
# 3        6.91      CA  1612202445
# 4       19.57      AU  1612202445

# %%
def plot_scat(y,y_label):
    lat_y = plt.scatter(cleaned_df['Lat'],cleaned_df[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(cleaned_df[y])-20,max(cleaned_df[y])+20)
    plt.grid()
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp = plot_scat(y='Max Temp',y_label='Max Temperature (F)')
lat_temp

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_humidity = plot_scat(y='Humidity',y_label='Humidity(%)')
lat_humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloud = plot_scat(y='Cloudiness',y_label='Cloudiness(%)')
lat_cloud

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_wind = plot_scat(y='Wind Speed',y_label='Wind Speed (mph)')
lat_wind

# %% [markdown]
# ## Linear Regression

# %%
north_hem = cleaned_df[cleaned_df['Lat'] >= 0]
south_hem = cleaned_df[cleaned_df['Lat'] < 0]

def plot_scat_north(y,y_label):
    lat_y = plt.scatter(north_hem['Lat'],north_hem[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(north_hem[y])-20,max(north_hem[y])+20)
    plt.grid()
    vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(north_hem['Lat'], north_hem[y])
    vc_fit = vc_slope * north_hem['Lat'] + vc_int
    plt.plot(north_hem['Lat'],vc_fit,'r',label='y={:.2f}x+{:.2f}'.format(vc_slope,vc_int))
    plt.legend(fontsize=9)
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))
    
def plot_scat_south(y,y_label):
    lat_y = plt.scatter(south_hem['Lat'],south_hem[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(south_hem[y])-20,max(south_hem[y])+20)
    plt.grid()
    vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(south_hem['Lat'], south_hem[y])
    vc_fit = vc_slope * south_hem['Lat'] + vc_int
    plt.plot(south_hem['Lat'],vc_fit,'r',label='y={:.2f}x+{:.2f}'.format(vc_slope,vc_int))
    plt.legend(fontsize=9)
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_temp_north = plot_scat_north(y='Max Temp',y_label='Max Temperature (F)')
lat_temp_north

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_temp_south = plot_scat_south(y='Max Temp',y_label='Max Temperature (F)')
lat_temp_south

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat_hum_north = plot_scat_north(y='Humidity',y_label='Humidity')
lat_hum_north

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat_hum_south = plot_scat_south(y='Humidity',y_label='Humidity')
lat_hum_south

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat_cloud_north = plot_scat_north(y='Cloudiness',y_label='Cloudiness')
lat_cloud_north

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat_cloud_south = plot_scat_south(y='Cloudiness',y_label='Cloudiness')
lat_cloud_south

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat_cloud_north = plot_scat_north(y='Wind Speed',y_label='Wind Speed')
lat_cloud_north

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat_cloud_south = plot_scat_south(y='Wind Speed',y_label='Wind Speed')
lat_cloud_south
