# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy import stats
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key
temp_units = 'imperial'

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Set URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# City and Set Number
city_num = 0
set_num = 1
# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if city_num > 48:
            city_num = 1
            set_num += 1
            city_two.append(city)
        else:
            city_num += 1
            city_two.append(city)
        print(f"Processing City Number {city_num} of set number {set_num}| {city}")
    except:
        print('no city found for this one')
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing City Number 1 of set number 1| ushuaia
# Processing City Number 2 of set number 1| punta arenas
# Processing City Number 3 of set number 1| yumen
# Processing City Number 4 of set number 1| rikitea
# Processing City Number 5 of set number 1| kawana waters
# Processing City Number 6 of set number 1| mackay
# Processing City Number 7 of set number 1| fairbanks
# Processing City Number 8 of set number 1| tres arroyos
# Processing City Number 9 of set number 1| albany
# Processing City Number 10 of set number 1| clyde river
# Processing City Number 11 of set number 1| grand forks
# Processing City Number 12 of set number 1| boyolangu
# Processing City Number 13 of set number 1| aksarka
# Processing City Number 14 of set number 1| tasiilaq
# Processing City Number 15 of set number 1| romny
# Processing City Number 16 of set number 1| busselton
# no city found for this one
# Processing City Number 17 of set number 1| atuona
# Processing City Number 18 of set number 1| kruisfontein
# Processing City Number 19 of set number 1| ventspils
# Processing City Number 20 of set number 1| cape town
# Processing City Number 21 of set number 1| floro
# no city found for this one
# Processing City Number 22 of set number 1| broome
# Processing City Number 23 of set number 1| khatanga
# Processing City Number 24 of set number 1| villa rica
# Processing City Number 25 of set number 1| bengkulu
# Processing City Number 26 of set number 1| dalvik
# no city found for this one
# Processing City Number 27 of set number 1| kamenka
# Processing City Number 28 of set number 1| tuktoyaktuk
# Processing City Number 29 of set number 1| bluff
# Processing City Number 30 of set number 1| xuddur
# Processing City Number 31 of set number 1| hobart
# no city found for this one
# Processing City Number 32 of set number 1| bilma
# Processing City Number 33 of set number 1| omsukchan
# Processing City Number 34 of set number 1| thompson
# Processing City Number 35 of set number 1| raton
# Processing City Number 36 of set number 1| kavaratti
# Processing City Number 37 of set number 1| vaini
# Processing City Number 38 of set number 1| margate
# Processing City Number 39 of set number 1| butaritari
# no city found for this one
# Processing City Number 40 of set number 1| abu dhabi
# no city found for this one
# Processing City Number 41 of set number 1| batagay
# Processing City Number 42 of set number 1| bambous virieux
# Processing City Number 43 of set number 1| hilo
# Processing City Number 44 of set number 1| ocos
# Processing City Number 45 of set number 1| yellowknife
# Processing City Number 46 of set number 1| fukue
# Processing City Number 47 of set number 1| casa nova
# Processing City Number 48 of set number 1| hermanus
# Processing City Number 49 of set number 1| souillac
# Processing City Number 1 of set number 2| torbay
# Processing City Number 2 of set number 2| soure
# Processing City Number 3 of set number 2| adre
# Processing City Number 4 of set number 2| ola
# Processing City Number 5 of set number 2| ucluelet
# no city found for this one
# Processing City Number 6 of set number 2| babu
# Processing City Number 7 of set number 2| grand river south east
# Processing City Number 8 of set number 2| port elizabeth
# Processing City Number 9 of set number 2| mar del plata
# Processing City Number 10 of set number 2| mataura
# no city found for this one
# Processing City Number 11 of set number 2| dongsheng
# Processing City Number 12 of set number 2| samarai
# Processing City Number 13 of set number 2| port alfred
# Processing City Number 14 of set number 2| portland
# Processing City Number 15 of set number 2| faanui
# Processing City Number 16 of set number 2| cayenne
# Processing City Number 17 of set number 2| sisimiut
# Processing City Number 18 of set number 2| chokurdakh
# Processing City Number 19 of set number 2| sao filipe
# Processing City Number 20 of set number 2| klaksvik
# Processing City Number 21 of set number 2| saskylakh
# Processing City Number 22 of set number 2| ghansor
# Processing City Number 23 of set number 2| saint-philippe
# Processing City Number 24 of set number 2| cherskiy
# Processing City Number 25 of set number 2| lingyuan
# no city found for this one
# Processing City Number 26 of set number 2| vendychany
# Processing City Number 27 of set number 2| new norfolk
# Processing City Number 28 of set number 2| ketchikan
# Processing City Number 29 of set number 2| nikolskoye
# Processing City Number 30 of set number 2| guymon
# Processing City Number 31 of set number 2| kabanjahe
# Processing City Number 32 of set number 2| tianpeng
# Processing City Number 33 of set number 2| avarua
# Processing City Number 34 of set number 2| najran
# Processing City Number 35 of set number 2| meulaboh
# Processing City Number 36 of set number 2| manavgat
# Processing City Number 37 of set number 2| sereflikochisar
# Processing City Number 38 of set number 2| bulgan
# Processing City Number 39 of set number 2| talnakh
# Processing City Number 40 of set number 2| limbang
# Processing City Number 41 of set number 2| kirkland lake
# Processing City Number 42 of set number 2| fort nelson
# Processing City Number 43 of set number 2| ponta do sol
# Processing City Number 44 of set number 2| namibe
# Processing City Number 45 of set number 2| alyangula
# Processing City Number 46 of set number 2| vasai
# Processing City Number 47 of set number 2| beringovskiy
# Processing City Number 48 of set number 2| mugur-aksy
# Processing City Number 49 of set number 2| anadyr
# Processing City Number 1 of set number 3| arraial do cabo
# Processing City Number 2 of set number 3| goderich
# no city found for this one
# no city found for this one
# Processing City Number 3 of set number 3| olafsvik
# no city found for this one
# no city found for this one
# Processing City Number 4 of set number 3| ulladulla
# Processing City Number 5 of set number 3| namatanai
# Processing City Number 6 of set number 3| mathathane
# Processing City Number 7 of set number 3| turayf
# Processing City Number 8 of set number 3| iguatemi
# Processing City Number 9 of set number 3| coquimbo
# Processing City Number 10 of set number 3| carnarvon
# Processing City Number 11 of set number 3| saravan
# Processing City Number 12 of set number 3| bambanglipuro
# Processing City Number 13 of set number 3| razdolnoye
# Processing City Number 14 of set number 3| yenagoa
# Processing City Number 15 of set number 3| maumere
# Processing City Number 16 of set number 3| takapau
# Processing City Number 17 of set number 3| georgetown
# Processing City Number 18 of set number 3| kudahuvadhoo
# no city found for this one
# Processing City Number 19 of set number 3| riyadh
# Processing City Number 20 of set number 3| gazanjyk
# no city found for this one
# Processing City Number 21 of set number 3| tiksi
# Processing City Number 22 of set number 3| bethel
# Processing City Number 23 of set number 3| grindavik
# Processing City Number 24 of set number 3| isangel
# Processing City Number 25 of set number 3| qaanaaq
# Processing City Number 26 of set number 3| half moon bay
# Processing City Number 27 of set number 3| srednekolymsk
# Processing City Number 28 of set number 3| coihaique
# no city found for this one
# Processing City Number 29 of set number 3| east london
# Processing City Number 30 of set number 3| yerbogachen
# Processing City Number 31 of set number 3| hithadhoo
# Processing City Number 32 of set number 3| kaitangata
# Processing City Number 33 of set number 3| itacoatiara
# Processing City Number 34 of set number 3| vila velha
# Processing City Number 35 of set number 3| bredasdorp
# Processing City Number 36 of set number 3| kropotkin
# Processing City Number 37 of set number 3| petropavlovsk-kamchatskiy
# Processing City Number 38 of set number 3| carballo
# no city found for this one
# Processing City Number 39 of set number 3| atasu
# Processing City Number 40 of set number 3| aklavik
# Processing City Number 41 of set number 3| kapaa
# Processing City Number 42 of set number 3| kodiak
# Processing City Number 43 of set number 3| sao jose da coroa grande
# Processing City Number 44 of set number 3| saint-augustin
# Processing City Number 45 of set number 3| tura
# Processing City Number 46 of set number 3| houma
# Processing City Number 47 of set number 3| sioux lookout
# Processing City Number 48 of set number 3| porto novo
# Processing City Number 49 of set number 3| guerrero negro
# Processing City Number 1 of set number 4| tautira
# Processing City Number 2 of set number 4| cartagena
# Processing City Number 3 of set number 4| puerto ayora
# Processing City Number 4 of set number 4| lasa
# Processing City Number 5 of set number 4| yarim
# Processing City Number 6 of set number 4| jamestown
# Processing City Number 7 of set number 4| ostrovnoy
# Processing City Number 8 of set number 4| katsuura
# Processing City Number 9 of set number 4| bandundu
# Processing City Number 10 of set number 4| makakilo city
# Processing City Number 11 of set number 4| kununurra
# Processing City Number 12 of set number 4| tenenkou
# no city found for this one
# Processing City Number 13 of set number 4| rio grande
# Processing City Number 14 of set number 4| prince rupert
# Processing City Number 15 of set number 4| cocobeach
# Processing City Number 16 of set number 4| barrow
# Processing City Number 17 of set number 4| kargasok
# Processing City Number 18 of set number 4| ribeira grande
# Processing City Number 19 of set number 4| khasan
# Processing City Number 20 of set number 4| xichang
# Processing City Number 21 of set number 4| jamame
# Processing City Number 22 of set number 4| nyurba
# Processing City Number 23 of set number 4| nouadhibou
# no city found for this one
# Processing City Number 24 of set number 4| hobyo
# Processing City Number 25 of set number 4| sawtell
# no city found for this one
# Processing City Number 26 of set number 4| muros
# Processing City Number 27 of set number 4| phuket
# Processing City Number 28 of set number 4| itarema
# Processing City Number 29 of set number 4| pevek
# Processing City Number 30 of set number 4| chara
# Processing City Number 31 of set number 4| mayo
# Processing City Number 32 of set number 4| akyab
# Processing City Number 33 of set number 4| sampit
# no city found for this one
# Processing City Number 34 of set number 4| chicama
# Processing City Number 35 of set number 4| hofn
# no city found for this one
# Processing City Number 36 of set number 4| turka
# no city found for this one
# Processing City Number 37 of set number 4| cabo san lucas
# Processing City Number 38 of set number 4| visby
# Processing City Number 39 of set number 4| mahon
# Processing City Number 40 of set number 4| mitsamiouli
# no city found for this one
# Processing City Number 41 of set number 4| umea
# Processing City Number 42 of set number 4| erenhot
# Processing City Number 43 of set number 4| lakes entrance
# Processing City Number 44 of set number 4| camacha
# Processing City Number 45 of set number 4| parabel
# Processing City Number 46 of set number 4| kailua
# Processing City Number 47 of set number 4| soe
# no city found for this one
# Processing City Number 48 of set number 4| roebourne
# Processing City Number 49 of set number 4| provideniya
# Processing City Number 1 of set number 5| sharan
# Processing City Number 2 of set number 5| lebu
# Processing City Number 3 of set number 5| macas
# Processing City Number 4 of set number 5| norman wells
# Processing City Number 5 of set number 5| victoria
# Processing City Number 6 of set number 5| lloydminster
# Processing City Number 7 of set number 5| bubaque
# Processing City Number 8 of set number 5| ust-tsilma
# Processing City Number 9 of set number 5| borisoglebskiy
# Processing City Number 10 of set number 5| tazovskiy
# Processing City Number 11 of set number 5| college
# Processing City Number 12 of set number 5| adrar
# Processing City Number 13 of set number 5| pajarito
# Processing City Number 14 of set number 5| touros
# Processing City Number 15 of set number 5| manggar
# Processing City Number 16 of set number 5| castro
# Processing City Number 17 of set number 5| tigil
# Processing City Number 18 of set number 5| geraldton
# Processing City Number 19 of set number 5| reftinskiy
# Processing City Number 20 of set number 5| dikson
# Processing City Number 21 of set number 5| waingapu
# Processing City Number 22 of set number 5| wamba
# Processing City Number 23 of set number 5| salalah
# no city found for this one
# Processing City Number 24 of set number 5| dzaoudzi
# no city found for this one
# no city found for this one
# Processing City Number 25 of set number 5| raisinghnagar
# Processing City Number 26 of set number 5| meridian
# Processing City Number 27 of set number 5| severo-kurilsk
# Processing City Number 28 of set number 5| kavieng
# Processing City Number 29 of set number 5| kupang
# no city found for this one
# Processing City Number 30 of set number 5| beaufort
# no city found for this one
# Processing City Number 31 of set number 5| ust-kulom
# Processing City Number 32 of set number 5| sitka
# Processing City Number 33 of set number 5| narsaq
# Processing City Number 34 of set number 5| adeje
# Processing City Number 35 of set number 5| glinka
# Processing City Number 36 of set number 5| kondoa
# Processing City Number 37 of set number 5| san isidro
# Processing City Number 38 of set number 5| ishcherskaya
# Processing City Number 39 of set number 5| upernavik
# Processing City Number 40 of set number 5| okhtyrka
# no city found for this one
# Processing City Number 41 of set number 5| mahebourg
# no city found for this one
# Processing City Number 42 of set number 5| sault sainte marie
# Processing City Number 43 of set number 5| bontang
# Processing City Number 44 of set number 5| sola
# Processing City Number 45 of set number 5| kargopol
# no city found for this one
# no city found for this one
# Processing City Number 46 of set number 5| kutum
# Processing City Number 47 of set number 5| cap malheureux
# Processing City Number 48 of set number 5| gediz
# Processing City Number 49 of set number 5| saint-louis
# Processing City Number 1 of set number 6| jakar
# Processing City Number 2 of set number 6| palmer
# Processing City Number 3 of set number 6| canton
# Processing City Number 4 of set number 6| tuatapere
# Processing City Number 5 of set number 6| hasaki
# Processing City Number 6 of set number 6| reforma
# Processing City Number 7 of set number 6| calama
# Processing City Number 8 of set number 6| buraydah
# Processing City Number 9 of set number 6| bathsheba
# Processing City Number 10 of set number 6| jacksonville
# Processing City Number 11 of set number 6| flin flon
# Processing City Number 12 of set number 6| dibrugarh
# Processing City Number 13 of set number 6| nanortalik
# Processing City Number 14 of set number 6| wewak
# Processing City Number 15 of set number 6| fereydunshahr
# Processing City Number 16 of set number 6| leningradskiy
# Processing City Number 17 of set number 6| pochutla
# no city found for this one
# Processing City Number 18 of set number 6| ust-nera
# Processing City Number 19 of set number 6| mount isa
# Processing City Number 20 of set number 6| sharjah
# Processing City Number 21 of set number 6| mys shmidta
# no city found for this one
# Processing City Number 22 of set number 6| palani
# no city found for this one
# Processing City Number 23 of set number 6| vardo
# Processing City Number 24 of set number 6| caconda
# Processing City Number 25 of set number 6| shenjiamen
# Processing City Number 26 of set number 6| morgan city
# Processing City Number 27 of set number 6| hotaka
# Processing City Number 28 of set number 6| chuy
# Processing City Number 29 of set number 6| sakakah
# Processing City Number 30 of set number 6| okhotsk
# Processing City Number 31 of set number 6| baikunthpur
# Processing City Number 32 of set number 6| diamantino
# Processing City Number 33 of set number 6| shimoda
# Processing City Number 34 of set number 6| pombas
# Processing City Number 35 of set number 6| fortuna
# Processing City Number 36 of set number 6| luganville
# Processing City Number 37 of set number 6| lithakia
# Processing City Number 38 of set number 6| miracema do tocantins
# Processing City Number 39 of set number 6| abu kamal
# Processing City Number 40 of set number 6| kindu
# Processing City Number 41 of set number 6| yukhnov
# Processing City Number 42 of set number 6| vila do maio
# Processing City Number 43 of set number 6| wanning
# Processing City Number 44 of set number 6| sur
# Processing City Number 45 of set number 6| khilok
# Processing City Number 46 of set number 6| beohari
# Processing City Number 47 of set number 6| broadford
# Processing City Number 48 of set number 6| ngorongoro
# Processing City Number 49 of set number 6| okha
# no city found for this one
# Processing City Number 1 of set number 7| pacific grove
# Processing City Number 2 of set number 7| byron bay
# Processing City Number 3 of set number 7| hovd
# Processing City Number 4 of set number 7| porto santo
# Processing City Number 5 of set number 7| north battleford
# Processing City Number 6 of set number 7| saldanha
# Processing City Number 7 of set number 7| saint-joseph
# Processing City Number 8 of set number 7| vrangel
# Processing City Number 9 of set number 7| kjollefjord
# Processing City Number 10 of set number 7| louga
# Processing City Number 11 of set number 7| zafra
# Processing City Number 12 of set number 7| laguna
# Processing City Number 13 of set number 7| hervey bay
# Processing City Number 14 of set number 7| padang
# Processing City Number 15 of set number 7| noumea
# Processing City Number 16 of set number 7| kaduqli
# Processing City Number 17 of set number 7| san cristobal
# Processing City Number 18 of set number 7| chifeng
# Processing City Number 19 of set number 7| terney
# Processing City Number 20 of set number 7| maxixe
# Processing City Number 21 of set number 7| urcos
# Processing City Number 22 of set number 7| benghazi
# Processing City Number 23 of set number 7| payo
# Processing City Number 24 of set number 7| shubarshi
# Processing City Number 25 of set number 7| karratha
# Processing City Number 26 of set number 7| semnan
# Processing City Number 27 of set number 7| lorengau
# Processing City Number 28 of set number 7| namie
# Processing City Number 29 of set number 7| port hedland
# Processing City Number 30 of set number 7| nemuro
# Processing City Number 31 of set number 7| naze
# no city found for this one
# Processing City Number 32 of set number 7| boa vista
# Processing City Number 33 of set number 7| constitucion
# no city found for this one
# Processing City Number 34 of set number 7| axim
# Processing City Number 35 of set number 7| formoso do araguaia
# no city found for this one
# Processing City Number 36 of set number 7| longyearbyen
# Processing City Number 37 of set number 7| piney green
# Processing City Number 38 of set number 7| esperance
# Processing City Number 39 of set number 7| yar-sale
# Processing City Number 40 of set number 7| tatawin
# Processing City Number 41 of set number 7| obo
# Processing City Number 42 of set number 7| san policarpo
# Processing City Number 43 of set number 7| vanimo
# Processing City Number 44 of set number 7| funadhoo
# Processing City Number 45 of set number 7| ushtobe
# Processing City Number 46 of set number 7| ancud
# Processing City Number 47 of set number 7| taft
# Processing City Number 48 of set number 7| springbok
# Processing City Number 49 of set number 7| san vicente
# Processing City Number 1 of set number 8| pachino
# Processing City Number 2 of set number 8| gorodishche
# Processing City Number 3 of set number 8| amahai
# Processing City Number 4 of set number 8| dobryanka
# Processing City Number 5 of set number 8| gornoye loo
# Processing City Number 6 of set number 8| thibodaux
# Processing City Number 7 of set number 8| sobolevo
# Processing City Number 8 of set number 8| saquarema
# Processing City Number 9 of set number 8| ponta delgada
# Processing City Number 10 of set number 8| brae
# Processing City Number 11 of set number 8| beloha
# Processing City Number 12 of set number 8| mount gambier
# Processing City Number 13 of set number 8| chapais
# Processing City Number 14 of set number 8| canon city
# Processing City Number 15 of set number 8| vanavara
# no city found for this one
# Processing City Number 16 of set number 8| libreville
# Processing City Number 17 of set number 8| tir pol
# Processing City Number 18 of set number 8| sorland
# Processing City Number 19 of set number 8| sanmenxia
# Processing City Number 20 of set number 8| putai
# Processing City Number 21 of set number 8| tilichiki
# Processing City Number 22 of set number 8| vestmannaeyjar
# Processing City Number 23 of set number 8| khandyga
# Processing City Number 24 of set number 8| aksay
# no city found for this one
# Processing City Number 25 of set number 8| singaraja
# Processing City Number 26 of set number 8| gasa
# Processing City Number 27 of set number 8| taiyuan
# Processing City Number 28 of set number 8| antofagasta
# Processing City Number 29 of set number 8| mantua
# Processing City Number 30 of set number 8| vaitape
# Processing City Number 31 of set number 8| windhoek
# Processing City Number 32 of set number 8| hay river
# no city found for this one
# Processing City Number 33 of set number 8| sakaiminato
# Processing City Number 34 of set number 8| lamu
# Processing City Number 35 of set number 8| san luis
# Processing City Number 36 of set number 8| paamiut
# no city found for this one
# Processing City Number 37 of set number 8| encheng
# Processing City Number 38 of set number 8| cidreira
# Processing City Number 39 of set number 8| ballina
# Processing City Number 40 of set number 8| kotaparh
# Processing City Number 41 of set number 8| bud
# Processing City Number 42 of set number 8| danjiangkou
# Processing City Number 43 of set number 8| gat
# Processing City Number 44 of set number 8| coromandel
# Processing City Number 45 of set number 8| berlevag
# Processing City Number 46 of set number 8| nhulunbuy
# Processing City Number 47 of set number 8| lerwick
# Processing City Number 48 of set number 8| aykhal
# Processing City Number 49 of set number 8| waipawa
# Processing City Number 1 of set number 9| southbridge
# Processing City Number 2 of set number 9| cheyenne
# Processing City Number 3 of set number 9| arica
# Processing City Number 4 of set number 9| houston
# Processing City Number 5 of set number 9| edgewater
# Processing City Number 6 of set number 9| alofi
# Processing City Number 7 of set number 9| santa rosa
# Processing City Number 8 of set number 9| sorong
# Processing City Number 9 of set number 9| changji
# Processing City Number 10 of set number 9| fredericksburg
# Processing City Number 11 of set number 9| tromso
# Processing City Number 12 of set number 9| nicoya
# Processing City Number 13 of set number 9| cam ranh
# Processing City Number 14 of set number 9| novouzensk
# Processing City Number 15 of set number 9| hanyang
# Processing City Number 16 of set number 9| kahului
# Processing City Number 17 of set number 9| beira
# no city found for this one
# Processing City Number 18 of set number 9| zhanakorgan
# Processing City Number 19 of set number 9| sangin
# Processing City Number 20 of set number 9| ambunti
# Processing City Number 21 of set number 9| atkarsk
# Processing City Number 22 of set number 9| dno
# Processing City Number 23 of set number 9| port macquarie
# Processing City Number 24 of set number 9| paso de los toros
# Processing City Number 25 of set number 9| khash
# Processing City Number 26 of set number 9| praia
# no city found for this one
# Processing City Number 27 of set number 9| port hardy
# Processing City Number 28 of set number 9| peleduy
# Processing City Number 29 of set number 9| phonhong
# Processing City Number 30 of set number 9| vera cruz
# Processing City Number 31 of set number 9| udachnyy
# Processing City Number 32 of set number 9| edirne
# Processing City Number 33 of set number 9| alice springs
# Processing City Number 34 of set number 9| antigonish
# Processing City Number 35 of set number 9| airai
# no city found for this one
# Processing City Number 36 of set number 9| bell ville
# Processing City Number 37 of set number 9| lavrentiya
# Processing City Number 38 of set number 9| garcia
# Processing City Number 39 of set number 9| ranong
# Processing City Number 40 of set number 9| altus
# Processing City Number 41 of set number 9| talara
# Processing City Number 42 of set number 9| victor harbor
# Processing City Number 43 of set number 9| zhezkazgan
# no city found for this one
# Processing City Number 44 of set number 9| ouadda
# Processing City Number 45 of set number 9| awjilah
# Processing City Number 46 of set number 9| mariinskiy posad
# Processing City Number 47 of set number 9| marquette
# Processing City Number 48 of set number 9| katangli
# Processing City Number 49 of set number 9| santa cecilia
# Processing City Number 1 of set number 10| salinas
# Processing City Number 2 of set number 10| kadnikov
# Processing City Number 3 of set number 10| marsa matruh
# Processing City Number 4 of set number 10| saint-pierre
# Processing City Number 5 of set number 10| necochea
# Processing City Number 6 of set number 10| zemio
# Processing City Number 7 of set number 10| concepcion del oro
# Processing City Number 8 of set number 10| tingi
# Processing City Number 9 of set number 10| yulara
# Processing City Number 10 of set number 10| remanso
# Processing City Number 11 of set number 10| kysyl-syr
# Processing City Number 12 of set number 10| nishihara
# Processing City Number 13 of set number 10| taltal
# no city found for this one
# Processing City Number 14 of set number 10| kurya
# Processing City Number 15 of set number 10| terrak
# Processing City Number 16 of set number 10| puerto leguizamo
# Processing City Number 17 of set number 10| sinnamary
# Processing City Number 18 of set number 10| cuamba
# Processing City Number 19 of set number 10| zyryanka
# Processing City Number 20 of set number 10| kenora
# Processing City Number 21 of set number 10| vestmanna
# no city found for this one
# Processing City Number 22 of set number 10| port blair
# Processing City Number 23 of set number 10| richards bay
# Processing City Number 24 of set number 10| lata
# Processing City Number 25 of set number 10| mbalmayo
# no city found for this one
# Processing City Number 26 of set number 10| solnechnyy
# Processing City Number 27 of set number 10| xiongzhou
# Processing City Number 28 of set number 10| forestville
# no city found for this one
# Processing City Number 29 of set number 10| suntar
# Processing City Number 30 of set number 10| bahia blanca
# Processing City Number 31 of set number 10| rocha
# no city found for this one
# Processing City Number 32 of set number 10| svetlogorsk
# Processing City Number 33 of set number 10| san quintin
# Processing City Number 34 of set number 10| gijon
# Processing City Number 35 of set number 10| alta floresta
# Processing City Number 36 of set number 10| moussoro
# Processing City Number 37 of set number 10| aburi
# Processing City Number 38 of set number 10| faya
# Processing City Number 39 of set number 10| garissa
# Processing City Number 40 of set number 10| ahipara
# no city found for this one
# Processing City Number 41 of set number 10| montrose
# no city found for this one
# Processing City Number 42 of set number 10| lompoc
# Processing City Number 43 of set number 10| taoudenni
# Processing City Number 44 of set number 10| orimattila
# Processing City Number 45 of set number 10| cap-aux-meules
# Processing City Number 46 of set number 10| aljezur
# no city found for this one
# Processing City Number 47 of set number 10| kuusamo
# Processing City Number 48 of set number 10| carlagan
# Processing City Number 49 of set number 10| homer
# Processing City Number 1 of set number 11| tutoia
# Processing City Number 2 of set number 11| saravena
# Processing City Number 3 of set number 11| pandan
# Processing City Number 4 of set number 11| sembe
# no city found for this one
# Processing City Number 5 of set number 11| novopokrovka
# Processing City Number 6 of set number 11| egvekinot
# Processing City Number 7 of set number 11| prainha
# Processing City Number 8 of set number 11| de-kastri
# Processing City Number 9 of set number 11| luderitz
# Processing City Number 10 of set number 11| sao joao da barra
# Processing City Number 11 of set number 11| quirinopolis
# Processing City Number 12 of set number 11| tucuman
# Processing City Number 13 of set number 11| kasama
# Processing City Number 14 of set number 11| moree
# Processing City Number 15 of set number 11| kautokeino
# Processing City Number 16 of set number 11| altamont
# Processing City Number 17 of set number 11| dingle
# Processing City Number 18 of set number 11| mkushi
# Processing City Number 19 of set number 11| qasigiannguit
# Processing City Number 20 of set number 11| premia de mar
# Processing City Number 21 of set number 11| maues
# Processing City Number 22 of set number 11| kabalo
# Processing City Number 23 of set number 11| wajima
# Processing City Number 24 of set number 11| bosobolo
# Processing City Number 25 of set number 11| wanaka
# Processing City Number 26 of set number 11| nueva gerona
# no city found for this one
# Processing City Number 27 of set number 11| erzurum
# Processing City Number 28 of set number 11| saquena
# Processing City Number 29 of set number 11| lagoa
# Processing City Number 30 of set number 11| maridi
# Processing City Number 31 of set number 11| zhangye
# Processing City Number 32 of set number 11| port hawkesbury
# Processing City Number 33 of set number 11| haines junction
# Processing City Number 34 of set number 11| grimshaw
# Processing City Number 35 of set number 11| irupi
# no city found for this one
# no city found for this one
# Processing City Number 36 of set number 11| shenzhen
# Processing City Number 37 of set number 11| nehe
# Processing City Number 38 of set number 11| mogadishu
# Processing City Number 39 of set number 11| santander jimenez
# Processing City Number 40 of set number 11| prieska
# Processing City Number 41 of set number 11| traverse city
# Processing City Number 42 of set number 11| takoradi
# Processing City Number 43 of set number 11| rorvik
# Processing City Number 44 of set number 11| worthington
# Processing City Number 45 of set number 11| labuhan
# Processing City Number 46 of set number 11| koindu
# Processing City Number 47 of set number 11| baracoa
# Processing City Number 48 of set number 11| sungaipenuh
# Processing City Number 49 of set number 11| mahibadhoo
# Processing City Number 1 of set number 12| straumen
# Processing City Number 2 of set number 12| dunedin
# Processing City Number 3 of set number 12| aguimes
# Processing City Number 4 of set number 12| zhigansk
# Processing City Number 5 of set number 12| cervo
# Processing City Number 6 of set number 12| pineville
# no city found for this one
# Processing City Number 7 of set number 12| dabhol
# Processing City Number 8 of set number 12| langsa
# no city found for this one
# Processing City Number 9 of set number 12| lopsmarka
# Processing City Number 10 of set number 12| bone
# Processing City Number 11 of set number 12| hanmer springs
# no city found for this one
# Processing City Number 12 of set number 12| mapiripan
# Processing City Number 13 of set number 12| asau
# Processing City Number 14 of set number 12| tarauaca
# Processing City Number 15 of set number 12| williston
# Processing City Number 16 of set number 12| kirakira
# Processing City Number 17 of set number 12| pechory
# Processing City Number 18 of set number 12| sunnyside
# Processing City Number 19 of set number 12| rabaul
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city":city_two,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Humidity":humidities,
    "Cloudiness":cloudinesses,
    "Wind Speed":wind_speeds,
    "Country":countries,
    "Date":dates
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#             city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        ushuaia -54.8000  -68.3000     53.60        54          75
# 1   punta arenas   8.9897  125.3400     74.08        83          92
# 2          yumen  40.2833   97.2000     25.27        69          15
# 3        rikitea -23.1203 -134.9692     78.22        70           6
# 4  kawana waters -23.3335  150.5051     75.20        83          40
#
#    Wind Speed Country        Date
# 0       12.66      AR  1612388347
# 1        4.34      PH  1612388509
# 2       18.03      CN  1612388510
# 3       12.48      PF  1612388226
# 4        9.22      AU  1612388510

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum_one_hund = weather_df[weather_df['Humidity'].astype('int64') >= 100]
hum_one_hund
# Out:
#                city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 7      tres arroyos  46.3231   11.0969     35.60       100          90
# 18        ventspils  57.3894   21.5606     24.80       100          40
# 49           torbay  47.6666  -52.7314     44.01       100          75
# 76        ketchikan  55.3422 -131.6461     37.40       100          90
# 79        kabanjahe   3.1001   98.4908     77.00       100          40
# 93        alyangula -13.8483  136.4192     78.80       100          99
# 157       kununurra -15.7667  128.7333     80.60       100          96
# 193             soe  -9.8607  124.2840     66.45       100         100
# 221        meridian  43.6121 -116.3915     39.00       100          40
# 224          kupang -10.1667  123.5833     77.00       100          75
# 233    ishcherskaya  43.7153   45.1264     33.80       100          90
# 292      ngorongoro  -3.2397   35.4875     51.89       100          61
# 343         pachino  36.7186   15.0907     50.00       100          75
# 426           airai  -8.9266  125.4092     61.43       100         100
# 485  cap-aux-meules  47.3821  -61.8597     41.00       100         100
# 486         aljezur  37.3191   -8.8033     55.99       100         100
# 494    novopokrovka  49.8425   36.5477     39.20       100          90
# 551            asau  46.4333   26.4000     37.40       100          90
#
#      Wind Speed Country        Date
# 7         18.41      IT  1612388510
# 18         2.30      LV  1612388512
# 49        27.63      CA  1612388517
# 76         5.75      US  1612388303
# 79         3.44      ID  1612388526
# 93         1.14      AU  1612388071
# 157        4.18      AU  1612388542
# 193        5.32      ID  1612388547
# 221        4.61      US  1612388552
# 224        2.30      ID  1612388552
# 233        2.24      RU  1612388554
# 292        2.64      TZ  1612388561
# 343        1.14      IT  1612388567
# 426        4.99      TL  1612388577
# 485        9.22      CA  1612388585
# 486        3.00      PT  1612388585
# 494        8.95      UA  1612388586
# 551       10.36      RO  1612388593

# %%
#  Get the indices of cities that have humidity over 100%.
hund_hum_indexes = [hum_one_hund[hum_one_hund['Humidity']==100].index.values]
hund_hum_indexes
# Out:
# [array([  7,  18,  49,  76,  79,  93, 157, 193, 221, 224, 233, 292, 343,
#         426, 485, 486, 494, 551], dtype=int64)]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cleaned_df = weather_df[weather_df['Humidity'].astype('int64') != 100]
cleaned_df.head()
cleaned_df.to_csv("output_data/cleaned_weather_data.csv", index=False, header=True)
#len(cleaned_df.index)

# %%
def plot_scat(y,y_label):
    lat_y = plt.scatter(cleaned_df['Lat'],cleaned_df[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(cleaned_df[y])-20,max(cleaned_df[y])+20)
    plt.grid()
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_temp = plot_scat(y='Max Temp',y_label='Max Temperature (F)')
lat_temp

# %% [markdown]
# ### This scatter plot shows how max temperature (F) changes as latitude increases.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_humidity = plot_scat(y='Humidity',y_label='Humidity(%)')
lat_humidity

# %% [markdown]
# ### This scatter plot shows how humidity (%) changes as latitude increases.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloud = plot_scat(y='Cloudiness',y_label='Cloudiness(%)')
lat_cloud

# %% [markdown]
# ### This scatter plot shows how cloudiness (%) changes as latitude increases.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_wind = plot_scat(y='Wind Speed',y_label='Wind Speed (mph)')
lat_wind

# %% [markdown]
# ### This scatter plot shows how wind speed (mph) changes as latitude increases.

# %% [markdown]
# ## Linear Regression

# %%
north_hem = cleaned_df[cleaned_df['Lat'] >= 0]
south_hem = cleaned_df[cleaned_df['Lat'] < 0]

def plot_scat_north(y,y_label):
    lat_y = plt.scatter(north_hem['Lat'],north_hem[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(north_hem[y])-20,max(north_hem[y])+20)
    plt.grid()
    vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(north_hem['Lat'], north_hem[y])
    vc_fit = vc_slope * north_hem['Lat'] + vc_int
    plt.plot(north_hem['Lat'],vc_fit,'r',label='y={:.2f}x+{:.2f}'.format(vc_slope,vc_int))
    plt.legend(fontsize=9)
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))
    
def plot_scat_south(y,y_label):
    lat_y = plt.scatter(south_hem['Lat'],south_hem[y],alpha=0.75,edgecolors='black')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(south_hem[y])-20,max(south_hem[y])+20)
    plt.grid()
    vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(south_hem['Lat'], south_hem[y])
    vc_fit = vc_slope * south_hem['Lat'] + vc_int
    plt.plot(south_hem['Lat'],vc_fit,'r',label='y={:.2f}x+{:.2f}'.format(vc_slope,vc_int))
    plt.legend(fontsize=9)
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_temp_north = plot_scat_north(y='Max Temp',y_label='Max Temperature (F)')
lat_temp_north

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
lat_temp_south = plot_scat_south(y='Max Temp',y_label='Max Temperature (F)')
lat_temp_south

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat_hum_north = plot_scat_north(y='Humidity',y_label='Humidity')
lat_hum_north

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
lat_hum_south = plot_scat_south(y='Humidity',y_label='Humidity')
lat_hum_south

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat_cloud_north = plot_scat_north(y='Cloudiness',y_label='Cloudiness')
lat_cloud_north

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
lat_cloud_south = plot_scat_south(y='Cloudiness',y_label='Cloudiness')
lat_cloud_south

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat_cloud_north = plot_scat_north(y='Wind Speed',y_label='Wind Speed')
lat_cloud_north

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
lat_cloud_south = plot_scat_south(y='Wind Speed',y_label='Wind Speed')
lat_cloud_south
